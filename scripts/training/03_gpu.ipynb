# %%
from tensorflow_addons.layers import InstanceNormalization
from tensorflow.keras.layers import Input, Dropout, Concatenate
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime
import os

# %%
from glob import glob
import cv2
from matplotlib.pyplot import imread

# %%
DATA_DIR_PATH = '/content/drive/My Drive/kikagaku/novelgan/data'

OUTPUT_DIR_PATH = os.path.join(DATA_DIR_PATH, '03_out')

# %%
os.makedirs(os.path.join(DATA_DIR_PATH, 'datasets'), exist_ok=True)

os.makedirs(os.path.join(OUTPUT_DIR_PATH, 'images'), exist_ok=True)
os.makedirs(os.path.join(OUTPUT_DIR_PATH, 'saved_models'), exist_ok=True)

# %%
class DataLoader():
    def __init__(self, dataset_name, img_res=(128, 128)):
        self.dataset_name = dataset_name
        self.img_res = img_res
        self.datasets_path = os.path.join(DATA_DIR_PATH, 'datasets')

    def load_data(self, domain, batch_size=1, is_testing=False):
        data_type = "train%s" % domain if not is_testing else "test%s" % domain
        #path = glob('./datasets/%s/%s/*' % (self.dataset_name, data_type))
        path = glob(os.path.join(self.datasets_path, self.dataset_name, data_type, '*'))

        batch_images = np.random.choice(path, size=batch_size)

        imgs = []
        for img_path in batch_images:
            img = self.imread(img_path)
            if not is_testing:
                #img = scipy.misc.imresize(img, self.img_res)
                img = cv2.resize(img, self.img_res)

                if np.random.random() > 0.5:
                    img = np.fliplr(img)
            else:
                #img = scipy.misc.imresize(img, self.img_res)
                img = cv2.resize(img, self.img_res)
            imgs.append(img)

        imgs = np.array(imgs)/127.5 - 1.

        return imgs

    def load_batch(self, batch_size=1, is_testing=False):
        data_type = "train" if not is_testing else "val"
        #path_A = glob('./datasets/%s/%sA/*' % (self.dataset_name, data_type))
        #path_B = glob('./datasets/%s/%sB/*' % (self.dataset_name, data_type))
        path_A = glob(os.path.join(self.datasets_path, self.dataset_name, '{}A'.format(data_type), '*'))
        path_B = glob(os.path.join(self.datasets_path, self.dataset_name, '{}B'.format(data_type), '*'))

        self.n_batches = int(min(len(path_A), len(path_B)) / batch_size)
        total_samples = self.n_batches * batch_size

        # Sample n_batches * batch_size from each path list so that model sees all
        # samples from both domains
        path_A = np.random.choice(path_A, total_samples, replace=False)
        path_B = np.random.choice(path_B, total_samples, replace=False)

        #for i in range(self.n_batches-1):
        for i in range(self.n_batches):
            batch_A = path_A[i*batch_size:(i+1)*batch_size]
            batch_B = path_B[i*batch_size:(i+1)*batch_size]
            imgs_A, imgs_B = [], []

            for img_A, img_B in zip(batch_A, batch_B):
                img_A = self.imread(img_A)
                img_B = self.imread(img_B)

                #img_A = scipy.misc.imresize(img_A, self.img_res)
                img_A = cv2.resize(img_A, self.img_res)
                #img_B = scipy.misc.imresize(img_B, self.img_res)
                img_B = cv2.resize(img_B, self.img_res)

                if not is_testing and np.random.random() > 0.5:
                    img_A = np.fliplr(img_A)
                    img_B = np.fliplr(img_B)

                imgs_A.append(img_A)
                imgs_B.append(img_B)

            imgs_A = np.array(imgs_A)/127.5 - 1.
            imgs_B = np.array(imgs_B)/127.5 - 1.

            yield imgs_A, imgs_B

    def load_img(self, path):
        img = self.imread(path)
        #img = scipy.misc.imresize(img, self.img_res)
        img = cv2.resize(img, self.img_res)
        img = img/127.5 - 1.
        return img[np.newaxis, :, :, :]

    def imread(self, path):
        #return scipy.misc.imread(path, mode='RGB').astype(np.float)
        return imread(path).astype(np.float)

# %%
IMG_ROWS = 128
IMG_COLS = 128

data_loader = DataLoader('novel2vangogh', img_res=(IMG_ROWS, IMG_COLS))

# %%
class CycleGAN:
    def __init__(self):
        self.history = pd.DataFrame({}, columns=[
            'epoch', 'epochs', 'batch_idx', 'batch_num', 'd_loss', 'acc', 'g_loss',
            'adv', 'recon', 'id', 'elapsed_time'])

        self.img_save_dir = os.path.join(OUTPUT_DIR_PATH, 'images')
        self.model_save_dir = os.path.join(OUTPUT_DIR_PATH, 'saved_models')
        self.combined_name = 'combined_model'

        self.train_cnt = 0

        # Input shape
        self.img_rows = IMG_ROWS
        self.img_cols = IMG_COLS
        self.channels = 3
        self.img_shape = (self.img_rows, self.img_cols, self.channels)

        self.d_A = None
        self.d_B = None
        self.g_AB = None
        self.g_BA = None
        self.combined = None

    def init(self, data_loader=None):
        # Configure data loader
        #self.dataset_name = 'apple2orange'
        #self.data_loader = DataLoader(dataset_name=self.dataset_name,
        #                              img_res=(self.img_rows, self.img_cols))
        if data_loader:
            self.data_loader = data_loader
            self.dataset_name = self.data_loader.dataset_name 

        # Calculate output shape of D (PatchGAN)
        patch = int(self.img_rows / 2**4)
        self.disc_patch = (patch, patch, 1)

        # Number of filters in the first layer of G and D
        self.gf = 32
        self.df = 64

        # Loss weights
        self.lambda_cycle = 10.0                    # Cycle-consistency loss
        self.lambda_id = 0.1 * self.lambda_cycle    # Identity loss

        optimizer = Adam(0.0002, 0.5)

        # Build and compile the discriminators
        self.d_A = self.build_discriminator()
        self.d_B = self.build_discriminator()
        self.d_A.compile(loss='mse',
                         optimizer=optimizer,
                         metrics=['accuracy'])
        self.d_B.compile(loss='mse',
                         optimizer=optimizer,
                         metrics=['accuracy'])

        # Build the generators
        self.g_AB = self.build_generator()
        self.g_BA = self.build_generator()

        # Input images from both domains
        img_A = Input(shape=self.img_shape)
        img_B = Input(shape=self.img_shape)

        # Translate images to the other domain
        fake_B = self.g_AB(img_A)
        fake_A = self.g_BA(img_B)

        # Translate images back to original domain
        reconstr_A = self.g_BA(fake_B)
        reconstr_B = self.g_AB(fake_A)

        # Identity mapping of images
        img_A_id = self.g_BA(img_A)
        img_B_id = self.g_AB(img_B)

        # For the combined model we will only train the generators
        self.d_A.trainable = False
        self.d_B.trainable = False

        # Discriminators determines validity of translated images
        valid_A = self.d_A(fake_A)
        valid_B = self.d_B(fake_B)

        # Combined model trains generators to fool discriminators
        self.combined = Model(inputs=[img_A, img_B],
                              outputs=[valid_A, valid_B,
                                       reconstr_A, reconstr_B,
                                       img_A_id, img_B_id ])
        self.combined.compile(loss=['mse', 'mse',
                                    'mae', 'mae',
                                    'mae', 'mae'],
                              loss_weights=[1, 1,
                                            self.lambda_cycle, self.lambda_cycle,
                                            self.lambda_id, self.lambda_id ],
                              optimizer=optimizer)

    def build_generator(self):
        """U-Net Generator"""

        def conv2d(layer_input, filters, f_size=4):
            """Layers used during downsampling"""
            d = Conv2D(filters, kernel_size=f_size, strides=2, padding='same')(layer_input)
            d = LeakyReLU(alpha=0.2)(d)
            d = InstanceNormalization()(d)
            return d

        def deconv2d(layer_input, skip_input, filters, f_size=4, dropout_rate=0):
            """Layers used during upsampling"""
            u = UpSampling2D(size=2)(layer_input)
            u = Conv2D(filters, kernel_size=f_size, strides=1, padding='same', activation='relu')(u)
            if dropout_rate:
                u = Dropout(dropout_rate)(u)
            u = InstanceNormalization()(u)
            u = Concatenate()([u, skip_input])
            return u

        # Image input
        d0 = Input(shape=self.img_shape)

        # Downsampling
        d1 = conv2d(d0, self.gf)
        d2 = conv2d(d1, self.gf*2)
        d3 = conv2d(d2, self.gf*4)
        d4 = conv2d(d3, self.gf*8)

        # Upsampling
        u1 = deconv2d(d4, d3, self.gf*4)
        u2 = deconv2d(u1, d2, self.gf*2)
        u3 = deconv2d(u2, d1, self.gf)

        u4 = UpSampling2D(size=2)(u3)
        output_img = Conv2D(self.channels, kernel_size=4, strides=1, padding='same', activation='tanh')(u4)

        return Model(d0, output_img)

    def build_discriminator(self):

        def d_layer(layer_input, filters, f_size=4, normalization=True):
            """Discriminator layer"""
            d = Conv2D(filters, kernel_size=f_size, strides=2, padding='same')(layer_input)
            d = LeakyReLU(alpha=0.2)(d)
            if normalization:
                d = InstanceNormalization()(d)
            return d

        img = Input(shape=self.img_shape)

        d1 = d_layer(img, self.df, normalization=False)
        d2 = d_layer(d1, self.df*2)
        d3 = d_layer(d2, self.df*4)
        d4 = d_layer(d3, self.df*8)

        validity = Conv2D(1, kernel_size=4, strides=1, padding='same')(d4)

        return Model(img, validity)

    def train(self, epochs, batch_size=1, sample_interval=-1, save_interval=-1):
        self.train_cnt += 1

        print(datetime.datetime.now().isoformat(), 'Start', self.train_cnt)

        start_time = datetime.datetime.now()

        # Adversarial loss ground truths
        valid = np.ones((batch_size,) + self.disc_patch)
        fake = np.zeros((batch_size,) + self.disc_patch)

        step_cnt = 1

        #for epoch in range(epochs):
        for epoch in range(1, epochs+1):
            #for batch_i, (imgs_A, imgs_B) in enumerate(self.data_loader.load_batch(batch_size)):
            for batch_i, (imgs_A, imgs_B) in enumerate(self.data_loader.load_batch(batch_size), 1):

                # Translate images to opposite domain
                fake_B = self.g_AB.predict(imgs_A)
                fake_A = self.g_BA.predict(imgs_B)

                # Train the discriminators (original images = real / translated = Fake)
                dA_loss_real = self.d_A.train_on_batch(imgs_A, valid)
                dA_loss_fake = self.d_A.train_on_batch(fake_A, fake)
                dA_loss = 0.5 * np.add(dA_loss_real, dA_loss_fake)

                dB_loss_real = self.d_B.train_on_batch(imgs_B, valid)
                dB_loss_fake = self.d_B.train_on_batch(fake_B, fake)
                dB_loss = 0.5 * np.add(dB_loss_real, dB_loss_fake)

                # Total disciminator loss
                d_loss = 0.5 * np.add(dA_loss, dB_loss)

                # Train the generators
                g_loss = self.combined.train_on_batch([imgs_A, imgs_B],
                                                      [valid, valid,
                                                       imgs_A, imgs_B,
                                                       imgs_A, imgs_B])

                elapsed_time = datetime.datetime.now() - start_time

                # Plot the progress
                # print("[Epoch %d/%d] [Batch %d/%d] [D loss: %f, acc: %3d%%] [G loss: %05f, adv: %05f, recon: %05f, id: %05f] time: %s " % (
                #     epoch, epochs,
                #     batch_i, self.data_loader.n_batches,
                #     d_loss[0], 100*d_loss[1],
                #     g_loss[0],
                #     np.mean(g_loss[1:3]),
                #     np.mean(g_loss[3:5]),
                #     np.mean(g_loss[5:6]),
                #     elapsed_time))
                self.history = self.history.append({
                    'epoch': epoch,
                    'epochs': epochs,
                    'batch_idx': batch_i,
                    'batch_num': self.data_loader.n_batches,
                    'd_loss': d_loss[0],
                    'acc': d_loss[1],
                    'g_loss': g_loss[0],
                    'adv': np.mean(g_loss[1:3]),
                    'recon': np.mean(g_loss[3:5]),
                    'id': np.mean(g_loss[5:6]),
                    'elapsed_time': elapsed_time
                }, ignore_index=True)

                # If at save interval => save generated image samples
                #if sample_interval > 0 and batch_i % sample_interval == 0:
                if sample_interval > 0 and step_cnt % sample_interval == 0:
                    print("[Epoch %d/%d] [Batch %d/%d] [D loss: %f, acc: %3d%%] [G loss: %05f, adv: %05f, recon: %05f, id: %05f] time: %s " % (
                        epoch, epochs,
                        batch_i, self.data_loader.n_batches,
                        d_loss[0], 100*d_loss[1],
                        g_loss[0],
                        np.mean(g_loss[1:3]),
                        np.mean(g_loss[3:5]),
                        np.mean(g_loss[5:6]),
                        elapsed_time))

                    self.sample_images(epoch, batch_i)

                #if save_interval > 0 and batch_i != 1 and (batch_i % save_interval) == 0:
                if save_interval > 0 and step_cnt % save_interval == 0:
                    file_suffix = '{}_{}_{}'.format(self.train_cnt, epoch, batch_i)
                    self.save_model_weights(self.combined, self.combined_name, file_suffix)

                step_cnt += 1

        print(datetime.datetime.now().isoformat(), 'End')

    def generate_image(self, img):
        return self.g_AB.predict(img)

    def sample_images(self, epoch, batch_i):
        dir_path = os.path.join(self.img_save_dir, self.dataset_name)

        #os.makedirs('images/%s' % self.dataset_name, exist_ok=True)
        os.makedirs(dir_path, exist_ok=True)

        r, c = 2, 3

        imgs_A = self.data_loader.load_data(domain="A", batch_size=1, is_testing=True)
        imgs_B = self.data_loader.load_data(domain="B", batch_size=1, is_testing=True)

        # Demo (for GIF)
        #imgs_A = self.data_loader.load_img('datasets/apple2orange/testA/n07740461_1541.jpg')
        #imgs_B = self.data_loader.load_img('datasets/apple2orange/testB/n07749192_4241.jpg')

        # Translate images to the other domain
        fake_B = self.g_AB.predict(imgs_A)
        fake_A = self.g_BA.predict(imgs_B)

        # Translate back to original domain
        reconstr_A = self.g_BA.predict(fake_B)
        reconstr_B = self.g_AB.predict(fake_A)

        gen_imgs = np.concatenate([imgs_A, fake_B, reconstr_A, imgs_B, fake_A, reconstr_B])

        # Rescale images 0 - 1
        gen_imgs = 0.5 * gen_imgs + 0.5

        titles = ['Original', 'Translated', 'Reconstructed']
        fig, axs = plt.subplots(r, c)
        cnt = 0

        for i in range(r):
            for j in range(c):
                axs[i, j].imshow(gen_imgs[cnt])
                axs[i, j].set_title(titles[j])
                axs[i, j].axis('off')
                cnt += 1

        #fig.savefig("images/%s/%d_%d.png" % (self.dataset_name, epoch, batch_i))
        file_path = os.path.join(dir_path, '{}_{}_{}.png'.format(self.train_cnt, epoch, batch_i))
        fig.savefig(file_path)

        plt.close()

    def plot_hisotry(self, columns=[]):
        if len(columns) == 0:
            columns = ['d_loss', 'g_loss']
            #columns = ['d_loss', 'acc', 'g_loss', 'adv', 'recon', 'id',]
        self.history[columns].plot()

    def save_models(self, file_suffix=None):
        self.save_model_weights(self.combined, self.combined_name, file_suffix)

    def save_model_weights(self, model, model_name, file_suffix=None):
        file_path = os.path.join(self.model_save_dir, self._create_h5_file_name(model_name, file_suffix))
        model.save_weights(file_path)

        print('Model weights saved.', model_name)

    def load_models(self, file_suffix=None):
        self.load_model_weights(self.combined_name, file_suffix)

    def load_model_weights(self, model_name, file_suffix=None):
        model = None

        if model_name == self.combined_name:
            model = self.combined
        else:
            print('Unsupported.', model_name)
            return

        if not model:
            print('Not initialized.', model_name)
            return

        file_path = os.path.join(self.model_save_dir, self._create_h5_file_name(model_name, file_suffix))

        if not os.path.exists(file_path):
            print('File Not found.', model_name)
            return

        model.load_weights(file_path)

        print('Model weights loaded.', model_name)

    def _create_h5_file_name(self, model_name, suffix=None):
        if suffix:
            return '{}_{}.h5'.format(model_name, suffix)
        else:
            return '{}.h5'.format(model_name)

# %%
gan = CycleGAN()
gan.init(data_loader=data_loader)
gan.train(epochs=50, batch_size=1, sample_interval=400, save_interval=400)
gan.history.to_csv(os.path.join(OUTPUT_DIR_PATH, 'history_2020073101.csv'))
# Out:
# 2020-07-30T22:07:20.054993 Start
# [Epoch 1/50] [Batch 400/400] [D loss: 0.318448, acc:  56%] [G loss: 8.099318, adv: 0.502868, recon: 0.324265, id: 0.354555] time: 0:10:28.599739
# Model weights saved. combined_model
# [Epoch 2/50] [Batch 400/400] [D loss: 0.169493, acc:  76%] [G loss: 7.559640, adv: 0.616230, recon: 0.286626, id: 0.280393] time: 0:11:37.545034
# Model weights saved. combined_model
# [Epoch 3/50] [Batch 400/400] [D loss: 0.320387, acc:  56%] [G loss: 5.663181, adv: 0.457191, recon: 0.214277, id: 0.242191] time: 0:12:39.136483
# Model weights saved. combined_model
# [Epoch 4/50] [Batch 400/400] [D loss: 0.113762, acc:  85%] [G loss: 6.810863, adv: 0.795560, recon: 0.236617, id: 0.240481] time: 0:13:40.816687
# Model weights saved. combined_model
# [Epoch 5/50] [Batch 400/400] [D loss: 0.108213, acc:  89%] [G loss: 9.235294, adv: 0.978684, recon: 0.329789, id: 0.284187] time: 0:14:43.020689
# Model weights saved. combined_model
# [Epoch 6/50] [Batch 400/400] [D loss: 0.177097, acc:  76%] [G loss: 6.521178, adv: 0.756202, recon: 0.227134, id: 0.264577] time: 0:15:45.572612
# Model weights saved. combined_model
# [Epoch 7/50] [Batch 400/400] [D loss: 0.173191, acc:  71%] [G loss: 6.590238, adv: 0.701710, recon: 0.233566, id: 0.267250] time: 0:16:48.609217
# Model weights saved. combined_model
# [Epoch 8/50] [Batch 400/400] [D loss: 0.259715, acc:  65%] [G loss: 6.727330, adv: 0.943658, recon: 0.221022, id: 0.258571] time: 0:17:50.837544
# Model weights saved. combined_model
# [Epoch 9/50] [Batch 400/400] [D loss: 0.088318, acc:  91%] [G loss: 8.655060, adv: 0.929039, recon: 0.308566, id: 0.235869] time: 0:18:52.953274
# Model weights saved. combined_model
# [Epoch 10/50] [Batch 400/400] [D loss: 0.113870, acc:  83%] [G loss: 5.894405, adv: 0.829190, recon: 0.192126, id: 0.198385] time: 0:19:55.684868
# Model weights saved. combined_model
# [Epoch 11/50] [Batch 400/400] [D loss: 0.072044, acc:  95%] [G loss: 8.070723, adv: 1.038627, recon: 0.271535, id: 0.262298] time: 0:20:58.468426
# Model weights saved. combined_model
# [Epoch 12/50] [Batch 400/400] [D loss: 0.109850, acc:  86%] [G loss: 6.462012, adv: 0.994655, recon: 0.202370, id: 0.242827] time: 0:22:00.771320
# Model weights saved. combined_model
# [Epoch 13/50] [Batch 400/400] [D loss: 0.105391, acc:  92%] [G loss: 10.371448, adv: 1.082632, recon: 0.375325, id: 0.329582] time: 0:23:03.601155
# Model weights saved. combined_model
# [Epoch 14/50] [Batch 400/400] [D loss: 0.062268, acc:  94%] [G loss: 7.911406, adv: 0.971314, recon: 0.271418, id: 0.320468] time: 0:24:06.528559
# Model weights saved. combined_model
# [Epoch 15/50] [Batch 400/400] [D loss: 0.080026, acc:  94%] [G loss: 8.976486, adv: 1.024823, recon: 0.314091, id: 0.270644] time: 0:25:09.495218
# Model weights saved. combined_model
# [Epoch 16/50] [Batch 400/400] [D loss: 0.051874, acc:  98%] [G loss: 7.848182, adv: 0.984719, recon: 0.267780, id: 0.327017] time: 0:26:12.227698
# Model weights saved. combined_model
# [Epoch 17/50] [Batch 400/400] [D loss: 0.051568, acc:  99%] [G loss: 7.469265, adv: 1.089226, recon: 0.241405, id: 0.254560] time: 0:27:15.832812
# Model weights saved. combined_model
# [Epoch 18/50] [Batch 400/400] [D loss: 0.053149, acc:  97%] [G loss: 8.192581, adv: 0.916265, recon: 0.286799, id: 0.314290] time: 0:28:18.716297
# Model weights saved. combined_model
# [Epoch 19/50] [Batch 400/400] [D loss: 0.031335, acc: 100%] [G loss: 7.000633, adv: 0.982428, recon: 0.228514, id: 0.252891] time: 0:29:21.363951
# Model weights saved. combined_model
# [Epoch 20/50] [Batch 400/400] [D loss: 0.163703, acc:  75%] [G loss: 6.277859, adv: 0.959436, recon: 0.195785, id: 0.251782] time: 0:30:24.209422
# Model weights saved. combined_model
# [Epoch 21/50] [Batch 400/400] [D loss: 0.039883, acc: 100%] [G loss: 7.438012, adv: 1.008930, recon: 0.242487, id: 0.345638] time: 0:31:26.922299
# Model weights saved. combined_model
# [Epoch 22/50] [Batch 400/400] [D loss: 0.092336, acc:  89%] [G loss: 6.168079, adv: 1.072698, recon: 0.181148, id: 0.263455] time: 0:32:30.665605
# Model weights saved. combined_model
# [Epoch 23/50] [Batch 400/400] [D loss: 0.060008, acc:  94%] [G loss: 7.569252, adv: 0.858726, recon: 0.266083, id: 0.260771] time: 0:33:33.787750
# Model weights saved. combined_model
# [Epoch 24/50] [Batch 400/400] [D loss: 0.073078, acc:  95%] [G loss: 7.666000, adv: 1.023528, recon: 0.260352, id: 0.211218] time: 0:34:36.680255
# Model weights saved. combined_model
# [Epoch 25/50] [Batch 400/400] [D loss: 0.032816, acc:  98%] [G loss: 6.401802, adv: 1.039441, recon: 0.195990, id: 0.231854] time: 0:35:40.049487
# Model weights saved. combined_model
# [Epoch 26/50] [Batch 400/400] [D loss: 0.028772, acc: 100%] [G loss: 8.673464, adv: 1.035714, recon: 0.300080, id: 0.226029] time: 0:36:42.519872
# Model weights saved. combined_model
# [Epoch 27/50] [Batch 400/400] [D loss: 0.056079, acc:  94%] [G loss: 6.026369, adv: 1.036873, recon: 0.180330, id: 0.185021] time: 0:37:46.276221
# Model weights saved. combined_model
# [Epoch 28/50] [Batch 400/400] [D loss: 0.076934, acc:  91%] [G loss: 7.520943, adv: 1.097056, recon: 0.242538, id: 0.223588] time: 0:38:49.380549
# Model weights saved. combined_model
# [Epoch 29/50] [Batch 400/400] [D loss: 0.027781, acc:  99%] [G loss: 5.803596, adv: 1.085069, recon: 0.162847, id: 0.236989] time: 0:39:52.320527
# Model weights saved. combined_model
# [Epoch 30/50] [Batch 400/400] [D loss: 0.020681, acc: 100%] [G loss: 5.821780, adv: 1.023010, recon: 0.170822, id: 0.188124] time: 0:40:55.414468
# Model weights saved. combined_model
# [Epoch 31/50] [Batch 400/400] [D loss: 0.116870, acc:  90%] [G loss: 6.812278, adv: 1.290417, recon: 0.191855, id: 0.230419] time: 0:41:58.324256
# Model weights saved. combined_model
# [Epoch 32/50] [Batch 400/400] [D loss: 0.015016, acc: 100%] [G loss: 7.201077, adv: 0.998182, recon: 0.235833, id: 0.197942] time: 0:43:02.248980
# Model weights saved. combined_model
# [Epoch 33/50] [Batch 400/400] [D loss: 0.033316, acc: 100%] [G loss: 5.794343, adv: 1.042543, recon: 0.168111, id: 0.179575] time: 0:44:05.438777
# Model weights saved. combined_model
# [Epoch 34/50] [Batch 400/400] [D loss: 0.058954, acc:  94%] [G loss: 5.644155, adv: 0.942337, recon: 0.169024, id: 0.214683] time: 0:45:09.048800
# Model weights saved. combined_model
# [Epoch 35/50] [Batch 400/400] [D loss: 0.015692, acc: 100%] [G loss: 6.658704, adv: 1.024518, recon: 0.210006, id: 0.188370] time: 0:46:12.507551
# Model weights saved. combined_model
# [Epoch 36/50] [Batch 400/400] [D loss: 0.023087, acc: 100%] [G loss: 6.014670, adv: 1.065162, recon: 0.175113, id: 0.191374] time: 0:47:15.935265
# Model weights saved. combined_model
# [Epoch 37/50] [Batch 400/400] [D loss: 0.016889, acc: 100%] [G loss: 5.844364, adv: 1.019880, recon: 0.173529, id: 0.188071] time: 0:48:19.645476
# Model weights saved. combined_model
# [Epoch 38/50] [Batch 400/400] [D loss: 0.019262, acc: 100%] [G loss: 6.038522, adv: 1.026801, recon: 0.177534, id: 0.256141] time: 0:49:23.137451
# Model weights saved. combined_model
# [Epoch 39/50] [Batch 400/400] [D loss: 0.037626, acc:  98%] [G loss: 7.348198, adv: 1.088929, recon: 0.234084, id: 0.179086] time: 0:50:25.410518
# Model weights saved. combined_model
# [Epoch 40/50] [Batch 400/400] [D loss: 0.012100, acc: 100%] [G loss: 5.589938, adv: 1.013147, recon: 0.161589, id: 0.167924] time: 0:51:28.695149
# Model weights saved. combined_model
# [Epoch 41/50] [Batch 400/400] [D loss: 0.014410, acc: 100%] [G loss: 6.607743, adv: 1.100211, recon: 0.201451, id: 0.170933] time: 0:52:31.955133
# Model weights saved. combined_model
# [Epoch 42/50] [Batch 400/400] [D loss: 0.013489, acc: 100%] [G loss: 6.253294, adv: 1.005532, recon: 0.194311, id: 0.161877] time: 0:53:35.145736
# Model weights saved. combined_model
# [Epoch 43/50] [Batch 400/400] [D loss: 0.018662, acc: 100%] [G loss: 7.000282, adv: 1.074987, recon: 0.218243, id: 0.238505] time: 0:54:38.355405
# Model weights saved. combined_model
# [Epoch 44/50] [Batch 400/400] [D loss: 0.014975, acc: 100%] [G loss: 6.488917, adv: 1.096331, recon: 0.192947, id: 0.172985] time: 0:55:40.651227
# Model weights saved. combined_model
# [Epoch 45/50] [Batch 400/400] [D loss: 0.004747, acc: 100%] [G loss: 6.405210, adv: 1.058921, recon: 0.191942, id: 0.230590] time: 0:56:43.469462
# Model weights saved. combined_model
# [Epoch 46/50] [Batch 400/400] [D loss: 0.008287, acc: 100%] [G loss: 6.563821, adv: 1.036819, recon: 0.204182, id: 0.159568] time: 0:57:47.164780
# Model weights saved. combined_model
# [Epoch 47/50] [Batch 400/400] [D loss: 0.006931, acc: 100%] [G loss: 6.390514, adv: 0.993447, recon: 0.200090, id: 0.181862] time: 0:58:50.645547
# Model weights saved. combined_model
# [Epoch 48/50] [Batch 400/400] [D loss: 0.010858, acc: 100%] [G loss: 6.575092, adv: 1.053246, recon: 0.199607, id: 0.260949] time: 0:59:54.455607
# Model weights saved. combined_model
# [Epoch 49/50] [Batch 400/400] [D loss: 0.005136, acc: 100%] [G loss: 5.726710, adv: 1.043573, recon: 0.165527, id: 0.154673] time: 1:00:57.657875
# Model weights saved. combined_model
# [Epoch 50/50] [Batch 400/400] [D loss: 0.011203, acc: 100%] [G loss: 7.269633, adv: 1.048832, recon: 0.234935, id: 0.154168] time: 1:02:00.672891
# Model weights saved. combined_model
# 2020-07-30T23:09:22.528680 End

# %%
gan = CycleGAN()
gan.init(data_loader=data_loader)
gan.load_models('50_400')
# Out:
# Model weights loaded. combined_model

# %%
gan.train(epochs=200, batch_size=1, sample_interval=400, save_interval=400)
gan.history.to_csv(os.path.join(OUTPUT_DIR_PATH, 'history_2020073102.csv'))
# Out:
# 2020-07-30T23:17:09.926719 Start 1
# [Epoch 1/200] [Batch 400/400] [D loss: 0.019429, acc: 100%] [G loss: 5.935740, adv: 1.054886, recon: 0.175282, id: 0.138764] time: 0:01:11.341923
# Model weights saved. combined_model
# [Epoch 2/200] [Batch 400/400] [D loss: 0.010913, acc: 100%] [G loss: 5.745028, adv: 0.973293, recon: 0.170018, id: 0.215800] time: 0:02:14.645626
# Model weights saved. combined_model
# [Epoch 3/200] [Batch 400/400] [D loss: 0.043485, acc:  98%] [G loss: 6.040347, adv: 0.916900, recon: 0.189217, id: 0.289044] time: 0:03:17.843937
# Model weights saved. combined_model
# [Epoch 4/200] [Batch 400/400] [D loss: 0.008820, acc: 100%] [G loss: 5.174778, adv: 0.980253, recon: 0.144622, id: 0.185695] time: 0:04:20.746840
# Model weights saved. combined_model
# [Epoch 5/200] [Batch 400/400] [D loss: 0.008472, acc: 100%] [G loss: 5.109237, adv: 1.012151, recon: 0.139038, id: 0.147693] time: 0:05:23.121850
# Model weights saved. combined_model
# [Epoch 6/200] [Batch 400/400] [D loss: 0.004157, acc: 100%] [G loss: 5.296380, adv: 0.995115, recon: 0.150393, id: 0.151415] time: 0:06:25.568335
# Model weights saved. combined_model
# [Epoch 7/200] [Batch 400/400] [D loss: 0.003468, acc: 100%] [G loss: 5.506522, adv: 1.026091, recon: 0.157451, id: 0.148785] time: 0:07:28.084792
# Model weights saved. combined_model
# [Epoch 8/200] [Batch 400/400] [D loss: 0.003272, acc: 100%] [G loss: 5.009667, adv: 1.032403, recon: 0.133786, id: 0.117836] time: 0:08:30.772044
# Model weights saved. combined_model
# [Epoch 9/200] [Batch 400/400] [D loss: 0.005105, acc: 100%] [G loss: 5.482401, adv: 1.000450, recon: 0.155325, id: 0.221614] time: 0:09:34.680975
# Model weights saved. combined_model
# [Epoch 10/200] [Batch 400/400] [D loss: 0.026496, acc:  99%] [G loss: 5.395191, adv: 1.100942, recon: 0.138949, id: 0.284029] time: 0:10:37.797413
# Model weights saved. combined_model
# [Epoch 11/200] [Batch 400/400] [D loss: 0.005252, acc: 100%] [G loss: 6.078427, adv: 0.965029, recon: 0.188718, id: 0.162850] time: 0:11:40.311934
# Model weights saved. combined_model
# [Epoch 12/200] [Batch 400/400] [D loss: 0.001385, acc: 100%] [G loss: 5.372627, adv: 0.998979, recon: 0.153681, id: 0.158574] time: 0:12:42.458019
# Model weights saved. combined_model
# [Epoch 13/200] [Batch 400/400] [D loss: 0.011510, acc: 100%] [G loss: 6.884891, adv: 1.095946, recon: 0.212336, id: 0.223660] time: 0:13:45.371265
# Model weights saved. combined_model
# [Epoch 14/200] [Batch 400/400] [D loss: 0.002445, acc: 100%] [G loss: 5.293465, adv: 1.002624, recon: 0.146556, id: 0.135675] time: 0:14:49.278460
# Model weights saved. combined_model
# [Epoch 15/200] [Batch 400/400] [D loss: 0.068802, acc:  90%] [G loss: 4.656695, adv: 0.923158, recon: 0.127842, id: 0.126256] time: 0:15:51.809153
# Model weights saved. combined_model
# [Epoch 16/200] [Batch 400/400] [D loss: 0.002789, acc: 100%] [G loss: 5.316777, adv: 1.034367, recon: 0.148747, id: 0.135055] time: 0:16:54.351158
# Model weights saved. combined_model
# [Epoch 17/200] [Batch 400/400] [D loss: 0.002349, acc: 100%] [G loss: 5.823075, adv: 1.018872, recon: 0.169938, id: 0.163649] time: 0:17:57.123549
# Model weights saved. combined_model
# [Epoch 18/200] [Batch 400/400] [D loss: 0.001189, acc: 100%] [G loss: 5.997420, adv: 1.002992, recon: 0.180476, id: 0.180937] time: 0:18:59.798788
# Model weights saved. combined_model
# [Epoch 19/200] [Batch 400/400] [D loss: 0.000999, acc: 100%] [G loss: 5.146770, adv: 1.010494, recon: 0.140991, id: 0.145251] time: 0:20:03.062477
# Model weights saved. combined_model
# [Epoch 20/200] [Batch 400/400] [D loss: 0.002143, acc: 100%] [G loss: 6.190919, adv: 1.006550, recon: 0.188210, id: 0.172955] time: 0:21:05.803822
# Model weights saved. combined_model
# [Epoch 21/200] [Batch 400/400] [D loss: 0.001711, acc: 100%] [G loss: 5.431166, adv: 1.007478, recon: 0.154644, id: 0.149139] time: 0:22:08.133175
# Model weights saved. combined_model
# [Epoch 22/200] [Batch 400/400] [D loss: 0.003111, acc: 100%] [G loss: 5.162567, adv: 1.046039, recon: 0.139221, id: 0.152202] time: 0:23:10.462070
# Model weights saved. combined_model
# [Epoch 23/200] [Batch 400/400] [D loss: 0.000910, acc: 100%] [G loss: 5.094182, adv: 1.006633, recon: 0.138356, id: 0.147425] time: 0:24:13.850492
# Model weights saved. combined_model
# [Epoch 24/200] [Batch 400/400] [D loss: 0.309949, acc:  58%] [G loss: 5.424616, adv: 1.037247, recon: 0.152382, id: 0.146927] time: 0:25:17.047066
# Model weights saved. combined_model
# [Epoch 25/200] [Batch 400/400] [D loss: 0.001120, acc: 100%] [G loss: 5.405525, adv: 1.018745, recon: 0.154880, id: 0.133456] time: 0:26:19.395584
# Model weights saved. combined_model
# [Epoch 26/200] [Batch 400/400] [D loss: 0.001786, acc: 100%] [G loss: 5.126733, adv: 1.015415, recon: 0.138888, id: 0.121771] time: 0:27:22.126939
# Model weights saved. combined_model
# [Epoch 27/200] [Batch 400/400] [D loss: 0.002008, acc: 100%] [G loss: 6.002006, adv: 0.983848, recon: 0.182133, id: 0.155499] time: 0:28:25.451120
# Model weights saved. combined_model
# [Epoch 28/200] [Batch 400/400] [D loss: 0.000803, acc: 100%] [G loss: 4.514440, adv: 1.008330, recon: 0.112663, id: 0.125704] time: 0:29:28.195485
# Model weights saved. combined_model
# [Epoch 29/200] [Batch 400/400] [D loss: 0.000788, acc: 100%] [G loss: 5.212861, adv: 1.007583, recon: 0.145182, id: 0.142543] time: 0:30:31.883194
# Model weights saved. combined_model
# [Epoch 30/200] [Batch 400/400] [D loss: 0.000763, acc: 100%] [G loss: 5.067418, adv: 0.998195, recon: 0.138832, id: 0.122413] time: 0:31:34.165288
# Model weights saved. combined_model
# [Epoch 31/200] [Batch 400/400] [D loss: 0.001445, acc: 100%] [G loss: 4.703450, adv: 1.002597, recon: 0.121509, id: 0.148745] time: 0:32:37.510269
# Model weights saved. combined_model
# [Epoch 32/200] [Batch 400/400] [D loss: 0.001058, acc: 100%] [G loss: 4.566271, adv: 1.009008, recon: 0.115000, id: 0.159583] time: 0:33:40.465312
# Model weights saved. combined_model
# [Epoch 33/200] [Batch 400/400] [D loss: 0.090715, acc:  81%] [G loss: 5.111313, adv: 0.974408, recon: 0.142186, id: 0.136687] time: 0:34:43.629205
# Model weights saved. combined_model
# [Epoch 34/200] [Batch 400/400] [D loss: 0.011676, acc: 100%] [G loss: 6.145501, adv: 1.099635, recon: 0.173485, id: 0.280704] time: 0:35:47.185146
# Model weights saved. combined_model
# [Epoch 35/200] [Batch 400/400] [D loss: 0.001084, acc: 100%] [G loss: 4.500096, adv: 1.009037, recon: 0.110759, id: 0.147615] time: 0:36:49.200671
# Model weights saved. combined_model
# [Epoch 36/200] [Batch 400/400] [D loss: 0.000771, acc: 100%] [G loss: 4.719825, adv: 0.999942, recon: 0.123146, id: 0.146398] time: 0:37:51.815075
# Model weights saved. combined_model
# [Epoch 37/200] [Batch 400/400] [D loss: 0.000690, acc: 100%] [G loss: 5.967299, adv: 0.994726, recon: 0.178745, id: 0.112971] time: 0:38:54.850813
# Model weights saved. combined_model
# [Epoch 38/200] [Batch 400/400] [D loss: 0.000445, acc: 100%] [G loss: 5.148909, adv: 1.007072, recon: 0.140519, id: 0.156928] time: 0:39:58.122959
# Model weights saved. combined_model
# [Epoch 39/200] [Batch 400/400] [D loss: 0.000683, acc: 100%] [G loss: 4.623483, adv: 0.999868, recon: 0.116993, id: 0.150367] time: 0:41:02.661724
# Model weights saved. combined_model
# [Epoch 40/200] [Batch 400/400] [D loss: 0.000444, acc: 100%] [G loss: 4.765680, adv: 0.999672, recon: 0.124183, id: 0.167219] time: 0:42:05.393254
# Model weights saved. combined_model
# [Epoch 41/200] [Batch 400/400] [D loss: 0.000454, acc: 100%] [G loss: 4.347749, adv: 1.004452, recon: 0.106884, id: 0.116656] time: 0:43:08.413861
# Model weights saved. combined_model
# [Epoch 42/200] [Batch 400/400] [D loss: 0.001154, acc: 100%] [G loss: 5.935750, adv: 1.024526, recon: 0.173016, id: 0.119450] time: 0:44:12.709882
# Model weights saved. combined_model
# [Epoch 43/200] [Batch 400/400] [D loss: 0.000848, acc: 100%] [G loss: 5.601785, adv: 1.010566, recon: 0.161203, id: 0.167200] time: 0:45:16.076820
# Model weights saved. combined_model
# [Epoch 44/200] [Batch 400/400] [D loss: 0.000525, acc: 100%] [G loss: 5.038264, adv: 1.009941, recon: 0.135328, id: 0.122700] time: 0:46:20.188007
# Model weights saved. combined_model
# [Epoch 45/200] [Batch 400/400] [D loss: 0.264450, acc:  55%] [G loss: 5.199159, adv: 1.001597, recon: 0.142439, id: 0.185616] time: 0:47:23.714933
# Model weights saved. combined_model
# [Epoch 46/200] [Batch 400/400] [D loss: 0.001065, acc: 100%] [G loss: 4.793719, adv: 0.996268, recon: 0.124701, id: 0.172049] time: 0:48:27.604471
# Model weights saved. combined_model
# [Epoch 47/200] [Batch 400/400] [D loss: 0.000618, acc: 100%] [G loss: 4.629523, adv: 1.015772, recon: 0.115340, id: 0.129745] time: 0:49:32.822694
# Model weights saved. combined_model
# [Epoch 48/200] [Batch 400/400] [D loss: 0.000655, acc: 100%] [G loss: 4.761998, adv: 1.011718, recon: 0.120522, id: 0.214002] time: 0:50:37.662675
# Model weights saved. combined_model
# [Epoch 49/200] [Batch 400/400] [D loss: 0.000293, acc: 100%] [G loss: 4.476029, adv: 1.004937, recon: 0.109248, id: 0.147174] time: 0:51:42.471446
# Model weights saved. combined_model
# [Epoch 50/200] [Batch 400/400] [D loss: 0.000453, acc: 100%] [G loss: 4.709817, adv: 1.003508, recon: 0.119714, id: 0.139957] time: 0:52:47.902635
# Model weights saved. combined_model
# [Epoch 51/200] [Batch 400/400] [D loss: 0.000800, acc: 100%] [G loss: 4.627433, adv: 0.994331, recon: 0.117186, id: 0.175852] time: 0:53:53.928782
# Model weights saved. combined_model
# [Epoch 52/200] [Batch 400/400] [D loss: 0.000695, acc: 100%] [G loss: 5.098784, adv: 0.990167, recon: 0.140577, id: 0.136339] time: 0:54:58.570076
# Model weights saved. combined_model
# [Epoch 53/200] [Batch 400/400] [D loss: 0.000409, acc: 100%] [G loss: 4.341417, adv: 0.997599, recon: 0.105589, id: 0.150666] time: 0:56:02.997819
# Model weights saved. combined_model
# [Epoch 54/200] [Batch 400/400] [D loss: 0.000477, acc: 100%] [G loss: 4.783414, adv: 0.989508, recon: 0.124883, id: 0.129934] time: 0:57:07.257336
# Model weights saved. combined_model
# [Epoch 55/200] [Batch 400/400] [D loss: 0.000596, acc: 100%] [G loss: 4.578407, adv: 1.014016, recon: 0.114586, id: 0.170701] time: 0:58:10.650741
# Model weights saved. combined_model
# [Epoch 56/200] [Batch 400/400] [D loss: 0.000307, acc: 100%] [G loss: 4.580149, adv: 1.004945, recon: 0.115280, id: 0.133588] time: 0:59:14.586569
# Model weights saved. combined_model
# [Epoch 57/200] [Batch 400/400] [D loss: 0.000467, acc: 100%] [G loss: 4.474192, adv: 1.009304, recon: 0.110817, id: 0.127566] time: 1:00:18.421044
# Model weights saved. combined_model
# [Epoch 58/200] [Batch 400/400] [D loss: 0.000388, acc: 100%] [G loss: 4.326191, adv: 0.998252, recon: 0.103702, id: 0.113600] time: 1:01:23.002920
# Model weights saved. combined_model
# [Epoch 59/200] [Batch 400/400] [D loss: 0.006259, acc: 100%] [G loss: 4.773227, adv: 0.983328, recon: 0.126834, id: 0.139958] time: 1:02:27.875531
# Model weights saved. combined_model
# [Epoch 60/200] [Batch 400/400] [D loss: 0.000405, acc: 100%] [G loss: 4.732391, adv: 0.997220, recon: 0.123666, id: 0.165000] time: 1:03:30.794051
# Model weights saved. combined_model
# [Epoch 61/200] [Batch 400/400] [D loss: 0.000381, acc: 100%] [G loss: 4.774239, adv: 1.009883, recon: 0.122397, id: 0.137342] time: 1:04:33.594375
# Model weights saved. combined_model
# [Epoch 62/200] [Batch 400/400] [D loss: 0.000393, acc: 100%] [G loss: 4.353622, adv: 0.999816, recon: 0.106230, id: 0.112432] time: 1:05:37.535170
# Model weights saved. combined_model
# [Epoch 63/200] [Batch 400/400] [D loss: 0.000362, acc: 100%] [G loss: 4.855581, adv: 1.000316, recon: 0.129449, id: 0.125428] time: 1:06:41.563694
# Model weights saved. combined_model
# [Epoch 64/200] [Batch 400/400] [D loss: 0.000286, acc: 100%] [G loss: 5.200526, adv: 1.009621, recon: 0.143597, id: 0.115580] time: 1:07:46.630056
# Model weights saved. combined_model
# [Epoch 65/200] [Batch 400/400] [D loss: 0.013137, acc:  99%] [G loss: 4.259840, adv: 0.881248, recon: 0.108868, id: 0.134868] time: 1:08:50.616279
# Model weights saved. combined_model
# [Epoch 66/200] [Batch 400/400] [D loss: 0.005446, acc: 100%] [G loss: 5.011111, adv: 0.985538, recon: 0.134408, id: 0.121897] time: 1:09:55.061606
# Model weights saved. combined_model
# [Epoch 67/200] [Batch 400/400] [D loss: 0.000417, acc: 100%] [G loss: 4.038203, adv: 1.007117, recon: 0.090085, id: 0.125527] time: 1:10:59.584202
# Model weights saved. combined_model
# [Epoch 68/200] [Batch 400/400] [D loss: 0.002715, acc: 100%] [G loss: 4.245820, adv: 0.973976, recon: 0.103201, id: 0.136994] time: 1:12:04.813831
# Model weights saved. combined_model
# [Epoch 69/200] [Batch 400/400] [D loss: 0.000342, acc: 100%] [G loss: 4.678620, adv: 0.995539, recon: 0.117669, id: 0.141540] time: 1:13:09.258312
# Model weights saved. combined_model
# [Epoch 70/200] [Batch 400/400] [D loss: 0.000479, acc: 100%] [G loss: 4.634904, adv: 1.006481, recon: 0.118013, id: 0.139720] time: 1:14:14.776745
# Model weights saved. combined_model
# [Epoch 71/200] [Batch 400/400] [D loss: 0.000356, acc: 100%] [G loss: 4.515261, adv: 1.003800, recon: 0.113036, id: 0.101137] time: 1:15:19.844910
# Model weights saved. combined_model
# [Epoch 72/200] [Batch 400/400] [D loss: 0.000317, acc: 100%] [G loss: 4.680945, adv: 0.998700, recon: 0.121555, id: 0.121739] time: 1:16:24.118484
# Model weights saved. combined_model
# [Epoch 73/200] [Batch 400/400] [D loss: 0.000476, acc: 100%] [G loss: 4.383009, adv: 0.999180, recon: 0.106460, id: 0.150213] time: 1:17:29.323674
# Model weights saved. combined_model
# [Epoch 74/200] [Batch 400/400] [D loss: 0.000183, acc: 100%] [G loss: 4.189295, adv: 1.001104, recon: 0.098812, id: 0.099832] time: 1:18:34.299660
# Model weights saved. combined_model
# [Epoch 75/200] [Batch 400/400] [D loss: 0.000316, acc: 100%] [G loss: 4.424287, adv: 1.000237, recon: 0.108431, id: 0.118263] time: 1:19:39.242086
# Model weights saved. combined_model
# [Epoch 76/200] [Batch 400/400] [D loss: 0.003274, acc: 100%] [G loss: 4.378927, adv: 0.985799, recon: 0.108613, id: 0.140759] time: 1:20:45.093295
# Model weights saved. combined_model
# [Epoch 77/200] [Batch 400/400] [D loss: 0.000739, acc: 100%] [G loss: 4.103274, adv: 0.986654, recon: 0.094504, id: 0.136100] time: 1:21:49.982227
# Model weights saved. combined_model
# [Epoch 78/200] [Batch 400/400] [D loss: 0.000315, acc: 100%] [G loss: 4.508296, adv: 1.001247, recon: 0.110492, id: 0.141392] time: 1:22:54.981316
# Model weights saved. combined_model
# [Epoch 79/200] [Batch 400/400] [D loss: 0.000363, acc: 100%] [G loss: 4.036835, adv: 1.004200, recon: 0.088262, id: 0.136519] time: 1:23:59.913695
# Model weights saved. combined_model
# [Epoch 80/200] [Batch 400/400] [D loss: 0.000162, acc: 100%] [G loss: 4.591887, adv: 0.995587, recon: 0.117583, id: 0.126757] time: 1:25:04.238856
# Model weights saved. combined_model
# [Epoch 81/200] [Batch 400/400] [D loss: 0.000221, acc: 100%] [G loss: 4.323493, adv: 0.998533, recon: 0.104431, id: 0.127687] time: 1:26:07.625326
# Model weights saved. combined_model
# [Epoch 82/200] [Batch 400/400] [D loss: 0.000261, acc: 100%] [G loss: 4.460351, adv: 0.997155, recon: 0.110275, id: 0.147697] time: 1:27:13.791806
# Model weights saved. combined_model
# [Epoch 83/200] [Batch 400/400] [D loss: 0.000151, acc: 100%] [G loss: 4.771914, adv: 1.000455, recon: 0.126274, id: 0.156528] time: 1:28:18.052070
# Model weights saved. combined_model
# [Epoch 84/200] [Batch 400/400] [D loss: 0.000242, acc: 100%] [G loss: 4.829544, adv: 0.995131, recon: 0.128264, id: 0.112621] time: 1:29:22.489426
# Model weights saved. combined_model
# [Epoch 85/200] [Batch 400/400] [D loss: 0.000702, acc: 100%] [G loss: 4.604308, adv: 1.011671, recon: 0.115797, id: 0.128498] time: 1:30:26.212851
# Model weights saved. combined_model
# [Epoch 86/200] [Batch 400/400] [D loss: 0.004110, acc: 100%] [G loss: 4.766054, adv: 1.042927, recon: 0.118733, id: 0.196476] time: 1:31:31.121873
# Model weights saved. combined_model
# [Epoch 87/200] [Batch 400/400] [D loss: 0.000656, acc: 100%] [G loss: 4.747518, adv: 0.992254, recon: 0.123915, id: 0.149794] time: 1:32:35.294697
# Model weights saved. combined_model
# [Epoch 88/200] [Batch 400/400] [D loss: 0.000566, acc: 100%] [G loss: 4.113212, adv: 1.002735, recon: 0.094487, id: 0.130115] time: 1:33:38.827333
# Model weights saved. combined_model
# [Epoch 89/200] [Batch 400/400] [D loss: 0.000273, acc: 100%] [G loss: 4.152643, adv: 1.001453, recon: 0.093483, id: 0.146549] time: 1:34:43.796428
# Model weights saved. combined_model
# [Epoch 90/200] [Batch 400/400] [D loss: 0.000193, acc: 100%] [G loss: 4.172957, adv: 0.996274, recon: 0.095530, id: 0.129149] time: 1:35:48.336937
# Model weights saved. combined_model
# [Epoch 91/200] [Batch 400/400] [D loss: 0.000251, acc: 100%] [G loss: 4.282916, adv: 1.003454, recon: 0.099936, id: 0.122868] time: 1:36:53.258475
# Model weights saved. combined_model
# [Epoch 92/200] [Batch 400/400] [D loss: 0.000128, acc: 100%] [G loss: 4.063126, adv: 1.002365, recon: 0.092379, id: 0.092005] time: 1:37:59.306143
# Model weights saved. combined_model
# [Epoch 93/200] [Batch 400/400] [D loss: 0.003289, acc: 100%] [G loss: 4.440886, adv: 1.045440, recon: 0.104864, id: 0.127360] time: 1:39:03.546985
# Model weights saved. combined_model
# [Epoch 94/200] [Batch 400/400] [D loss: 0.000313, acc: 100%] [G loss: 5.499618, adv: 0.996686, recon: 0.156867, id: 0.130449] time: 1:40:07.996213
# Model weights saved. combined_model
# [Epoch 95/200] [Batch 400/400] [D loss: 0.000296, acc: 100%] [G loss: 4.419442, adv: 1.001428, recon: 0.105686, id: 0.121066] time: 1:41:12.493734
# Model weights saved. combined_model
# [Epoch 96/200] [Batch 400/400] [D loss: 0.025046, acc:  99%] [G loss: 3.939857, adv: 0.914434, recon: 0.093588, id: 0.128049] time: 1:42:18.766680
# Model weights saved. combined_model
# [Epoch 97/200] [Batch 400/400] [D loss: 0.000310, acc: 100%] [G loss: 5.169806, adv: 1.008890, recon: 0.141258, id: 0.126505] time: 1:43:23.415814
# Model weights saved. combined_model
# [Epoch 98/200] [Batch 400/400] [D loss: 0.000167, acc: 100%] [G loss: 3.876859, adv: 0.999222, recon: 0.082523, id: 0.108382] time: 1:44:28.060842
# Model weights saved. combined_model
# [Epoch 99/200] [Batch 400/400] [D loss: 0.002044, acc: 100%] [G loss: 4.498525, adv: 1.001656, recon: 0.111266, id: 0.128377] time: 1:45:33.852973
# Model weights saved. combined_model
# [Epoch 100/200] [Batch 400/400] [D loss: 0.000235, acc: 100%] [G loss: 3.947855, adv: 1.000561, recon: 0.085913, id: 0.123523] time: 1:46:39.205294
# Model weights saved. combined_model
# [Epoch 101/200] [Batch 400/400] [D loss: 0.000233, acc: 100%] [G loss: 4.667083, adv: 1.000572, recon: 0.116780, id: 0.142993] time: 1:47:45.306333
# Model weights saved. combined_model
# [Epoch 102/200] [Batch 400/400] [D loss: 0.000142, acc: 100%] [G loss: 4.028870, adv: 1.000616, recon: 0.090801, id: 0.117400] time: 1:48:51.032771
# Model weights saved. combined_model
# [Epoch 103/200] [Batch 400/400] [D loss: 0.000177, acc: 100%] [G loss: 4.780101, adv: 1.002692, recon: 0.122270, id: 0.104725] time: 1:49:58.548396
# Model weights saved. combined_model
# [Epoch 104/200] [Batch 400/400] [D loss: 0.001352, acc: 100%] [G loss: 4.348050, adv: 1.006640, recon: 0.105310, id: 0.121385] time: 1:51:02.672279
# Model weights saved. combined_model
# [Epoch 105/200] [Batch 400/400] [D loss: 0.000687, acc: 100%] [G loss: 4.056028, adv: 1.019802, recon: 0.090156, id: 0.117258] time: 1:52:07.884018
# Model weights saved. combined_model
# [Epoch 106/200] [Batch 400/400] [D loss: 0.000325, acc: 100%] [G loss: 4.017292, adv: 0.995286, recon: 0.090561, id: 0.119878] time: 1:53:14.483754
# Model weights saved. combined_model
# [Epoch 107/200] [Batch 400/400] [D loss: 0.000359, acc: 100%] [G loss: 4.219613, adv: 1.004203, recon: 0.098741, id: 0.127567] time: 1:54:19.887573
# Model weights saved. combined_model
# [Epoch 108/200] [Batch 400/400] [D loss: 0.000441, acc: 100%] [G loss: 4.539722, adv: 1.011029, recon: 0.113453, id: 0.137975] time: 1:55:24.968657
# Model weights saved. combined_model
# [Epoch 109/200] [Batch 400/400] [D loss: 0.000295, acc: 100%] [G loss: 3.846416, adv: 1.001296, recon: 0.081672, id: 0.109644] time: 1:56:30.097984
# Model weights saved. combined_model
# [Epoch 110/200] [Batch 400/400] [D loss: 0.000205, acc: 100%] [G loss: 3.933420, adv: 1.004074, recon: 0.084268, id: 0.138543] time: 1:57:36.433285
# Model weights saved. combined_model
# [Epoch 111/200] [Batch 400/400] [D loss: 0.000318, acc: 100%] [G loss: 4.423996, adv: 1.003228, recon: 0.108692, id: 0.107376] time: 1:58:41.634843
# Model weights saved. combined_model
# [Epoch 112/200] [Batch 400/400] [D loss: 0.000743, acc: 100%] [G loss: 4.038712, adv: 0.990589, recon: 0.092051, id: 0.141872] time: 1:59:46.531367
# Model weights saved. combined_model
# [Epoch 113/200] [Batch 400/400] [D loss: 0.000350, acc: 100%] [G loss: 4.352953, adv: 1.004075, recon: 0.105134, id: 0.112720] time: 2:00:50.562569
# Model weights saved. combined_model
# [Epoch 114/200] [Batch 400/400] [D loss: 0.000578, acc: 100%] [G loss: 4.104959, adv: 1.011061, recon: 0.093102, id: 0.118260] time: 2:01:56.284548
# Model weights saved. combined_model
# [Epoch 115/200] [Batch 400/400] [D loss: 0.000295, acc: 100%] [G loss: 4.018046, adv: 1.002336, recon: 0.088992, id: 0.146743] time: 2:03:00.648515
# Model weights saved. combined_model
# [Epoch 116/200] [Batch 400/400] [D loss: 0.000241, acc: 100%] [G loss: 3.996078, adv: 1.003833, recon: 0.088388, id: 0.121306] time: 2:04:04.582731
# Model weights saved. combined_model
# [Epoch 117/200] [Batch 400/400] [D loss: 0.000295, acc: 100%] [G loss: 3.735981, adv: 1.004074, recon: 0.075868, id: 0.108795] time: 2:05:09.902375
# Model weights saved. combined_model
# [Epoch 118/200] [Batch 400/400] [D loss: 0.000261, acc: 100%] [G loss: 4.080906, adv: 0.998819, recon: 0.091226, id: 0.111245] time: 2:06:15.393861
# Model weights saved. combined_model
# [Epoch 119/200] [Batch 400/400] [D loss: 0.000144, acc: 100%] [G loss: 3.946500, adv: 1.001652, recon: 0.086644, id: 0.118110] time: 2:07:19.247155
# Model weights saved. combined_model
# [Epoch 120/200] [Batch 400/400] [D loss: 0.000659, acc: 100%] [G loss: 4.031621, adv: 0.985572, recon: 0.090756, id: 0.130540] time: 2:08:23.380569
# Model weights saved. combined_model
# [Epoch 121/200] [Batch 400/400] [D loss: 0.000259, acc: 100%] [G loss: 4.048766, adv: 1.003477, recon: 0.091232, id: 0.131645] time: 2:09:26.837766
# Model weights saved. combined_model
# [Epoch 122/200] [Batch 400/400] [D loss: 0.000273, acc: 100%] [G loss: 4.433198, adv: 1.004373, recon: 0.109858, id: 0.138212] time: 2:10:32.756197
# Model weights saved. combined_model
# [Epoch 123/200] [Batch 400/400] [D loss: 0.000169, acc: 100%] [G loss: 3.873582, adv: 1.000629, recon: 0.079969, id: 0.143274] time: 2:11:36.920182
# Model weights saved. combined_model
# [Epoch 124/200] [Batch 400/400] [D loss: 0.000209, acc: 100%] [G loss: 3.950818, adv: 1.001601, recon: 0.086889, id: 0.114853] time: 2:12:40.936911
# Model weights saved. combined_model
# [Epoch 125/200] [Batch 400/400] [D loss: 0.000120, acc: 100%] [G loss: 4.062614, adv: 1.000607, recon: 0.093393, id: 0.097331] time: 2:13:45.287652
# Model weights saved. combined_model
# [Epoch 126/200] [Batch 400/400] [D loss: 0.000122, acc: 100%] [G loss: 3.950832, adv: 1.001367, recon: 0.085645, id: 0.119781] time: 2:14:51.699714
# Model weights saved. combined_model
# [Epoch 127/200] [Batch 400/400] [D loss: 0.000174, acc: 100%] [G loss: 3.883112, adv: 1.001688, recon: 0.083238, id: 0.122013] time: 2:15:56.294472
# Model weights saved. combined_model
# [Epoch 128/200] [Batch 400/400] [D loss: 0.000908, acc: 100%] [G loss: 4.017392, adv: 0.983815, recon: 0.091217, id: 0.132915] time: 2:17:00.146737
# Model weights saved. combined_model
# [Epoch 129/200] [Batch 400/400] [D loss: 0.000213, acc: 100%] [G loss: 3.985496, adv: 1.008528, recon: 0.088297, id: 0.107162] time: 2:18:03.735802
# Model weights saved. combined_model
# [Epoch 130/200] [Batch 400/400] [D loss: 0.000157, acc: 100%] [G loss: 3.781859, adv: 0.998370, recon: 0.078692, id: 0.116872] time: 2:19:09.559588
# Model weights saved. combined_model
# [Epoch 131/200] [Batch 400/400] [D loss: 0.003240, acc: 100%] [G loss: 3.740243, adv: 0.977909, recon: 0.078989, id: 0.117008] time: 2:20:14.887414
# Model weights saved. combined_model
# [Epoch 132/200] [Batch 400/400] [D loss: 0.000108, acc: 100%] [G loss: 3.895415, adv: 1.000015, recon: 0.084398, id: 0.122883] time: 2:21:19.243663
# Model weights saved. combined_model
# [Epoch 133/200] [Batch 400/400] [D loss: 0.000108, acc: 100%] [G loss: 3.630783, adv: 1.001275, recon: 0.072486, id: 0.100033] time: 2:22:24.134414
# Model weights saved. combined_model
# [Epoch 134/200] [Batch 400/400] [D loss: 0.000144, acc: 100%] [G loss: 3.648342, adv: 0.997911, recon: 0.072356, id: 0.115675] time: 2:23:28.570980
# Model weights saved. combined_model
# [Epoch 135/200] [Batch 400/400] [D loss: 0.001154, acc: 100%] [G loss: 3.882022, adv: 1.044199, recon: 0.079487, id: 0.110284] time: 2:24:34.546021
# Model weights saved. combined_model
# [Epoch 136/200] [Batch 400/400] [D loss: 0.000272, acc: 100%] [G loss: 4.404135, adv: 1.004918, recon: 0.105200, id: 0.173101] time: 2:25:39.240791
# Model weights saved. combined_model
# [Epoch 137/200] [Batch 400/400] [D loss: 0.000463, acc: 100%] [G loss: 4.975851, adv: 0.991839, recon: 0.132517, id: 0.241455] time: 2:26:43.778316
# Model weights saved. combined_model
# [Epoch 138/200] [Batch 400/400] [D loss: 0.000197, acc: 100%] [G loss: 3.906188, adv: 0.999637, recon: 0.085533, id: 0.114741] time: 2:27:48.092656
# Model weights saved. combined_model
# [Epoch 139/200] [Batch 400/400] [D loss: 0.000128, acc: 100%] [G loss: 3.945568, adv: 1.000452, recon: 0.087285, id: 0.104094] time: 2:28:54.377938
# Model weights saved. combined_model
# [Epoch 140/200] [Batch 400/400] [D loss: 0.029020, acc:  97%] [G loss: 4.126336, adv: 1.056574, recon: 0.089080, id: 0.120056] time: 2:29:58.003525
# Model weights saved. combined_model
# [Epoch 141/200] [Batch 400/400] [D loss: 0.001484, acc: 100%] [G loss: 4.274774, adv: 1.051326, recon: 0.097275, id: 0.119452] time: 2:31:01.794278
# Model weights saved. combined_model
# [Epoch 142/200] [Batch 400/400] [D loss: 0.000373, acc: 100%] [G loss: 3.805762, adv: 1.003130, recon: 0.079977, id: 0.121665] time: 2:32:05.441503
# Model weights saved. combined_model
# [Epoch 143/200] [Batch 400/400] [D loss: 0.000247, acc: 100%] [G loss: 4.743476, adv: 0.996196, recon: 0.123354, id: 0.120343] time: 2:33:08.922280
# Model weights saved. combined_model
# [Epoch 144/200] [Batch 400/400] [D loss: 0.000228, acc: 100%] [G loss: 4.041208, adv: 0.999921, recon: 0.091325, id: 0.120579] time: 2:34:15.614650
# Model weights saved. combined_model
# [Epoch 145/200] [Batch 400/400] [D loss: 0.000154, acc: 100%] [G loss: 3.974829, adv: 0.995110, recon: 0.088956, id: 0.108436] time: 2:35:20.294415
# Model weights saved. combined_model
# [Epoch 146/200] [Batch 400/400] [D loss: 0.000944, acc: 100%] [G loss: 3.999525, adv: 1.006037, recon: 0.090009, id: 0.118412] time: 2:36:25.603428
# Model weights saved. combined_model
# [Epoch 147/200] [Batch 400/400] [D loss: 0.000140, acc: 100%] [G loss: 4.301962, adv: 1.001915, recon: 0.103071, id: 0.122354] time: 2:37:30.057122
# Model weights saved. combined_model
# [Epoch 148/200] [Batch 400/400] [D loss: 0.000148, acc: 100%] [G loss: 4.045746, adv: 0.996916, recon: 0.091363, id: 0.141271] time: 2:38:35.885996
# Model weights saved. combined_model
# [Epoch 149/200] [Batch 400/400] [D loss: 0.000120, acc: 100%] [G loss: 3.748890, adv: 0.999502, recon: 0.078019, id: 0.100601] time: 2:39:40.679489
# Model weights saved. combined_model
# [Epoch 150/200] [Batch 400/400] [D loss: 0.000119, acc: 100%] [G loss: 4.211923, adv: 0.998834, recon: 0.099364, id: 0.109086] time: 2:40:45.108243
# Model weights saved. combined_model
# [Epoch 151/200] [Batch 400/400] [D loss: 0.000173, acc: 100%] [G loss: 3.760117, adv: 0.999430, recon: 0.078100, id: 0.099895] time: 2:41:49.765526
# Model weights saved. combined_model
# [Epoch 152/200] [Batch 400/400] [D loss: 0.000145, acc: 100%] [G loss: 4.163383, adv: 1.001268, recon: 0.095735, id: 0.096595] time: 2:42:52.966858
# Model weights saved. combined_model
# [Epoch 153/200] [Batch 400/400] [D loss: 0.000234, acc: 100%] [G loss: 3.857092, adv: 0.998032, recon: 0.082508, id: 0.117059] time: 2:43:57.662629
# Model weights saved. combined_model
# [Epoch 154/200] [Batch 400/400] [D loss: 0.000278, acc: 100%] [G loss: 3.956545, adv: 0.993375, recon: 0.087929, id: 0.096874] time: 2:45:01.503037
# Model weights saved. combined_model
# [Epoch 155/200] [Batch 400/400] [D loss: 0.000289, acc: 100%] [G loss: 3.724517, adv: 1.013043, recon: 0.075247, id: 0.123064] time: 2:46:06.350153
# Model weights saved. combined_model
# [Epoch 156/200] [Batch 400/400] [D loss: 0.000132, acc: 100%] [G loss: 4.306124, adv: 0.998674, recon: 0.103406, id: 0.146550] time: 2:47:10.611260
# Model weights saved. combined_model
# [Epoch 157/200] [Batch 400/400] [D loss: 0.000109, acc: 100%] [G loss: 3.987075, adv: 0.998725, recon: 0.087835, id: 0.112003] time: 2:48:14.814634
# Model weights saved. combined_model
# [Epoch 158/200] [Batch 400/400] [D loss: 0.023484, acc: 100%] [G loss: 4.214911, adv: 0.935860, recon: 0.106103, id: 0.131478] time: 2:49:21.381434
# Model weights saved. combined_model
# [Epoch 159/200] [Batch 400/400] [D loss: 0.000241, acc: 100%] [G loss: 3.840099, adv: 1.006878, recon: 0.079812, id: 0.106966] time: 2:50:26.465933
# Model weights saved. combined_model
# [Epoch 160/200] [Batch 400/400] [D loss: 0.000146, acc: 100%] [G loss: 3.959179, adv: 1.004249, recon: 0.086757, id: 0.122523] time: 2:51:29.777596
# Model weights saved. combined_model
# [Epoch 161/200] [Batch 400/400] [D loss: 0.000147, acc: 100%] [G loss: 3.727055, adv: 1.000162, recon: 0.076029, id: 0.135739] time: 2:52:32.884273
# Model weights saved. combined_model
# [Epoch 162/200] [Batch 400/400] [D loss: 0.000173, acc: 100%] [G loss: 3.833549, adv: 1.004127, recon: 0.081653, id: 0.122116] time: 2:53:36.528705
# Model weights saved. combined_model
# [Epoch 163/200] [Batch 400/400] [D loss: 0.000094, acc: 100%] [G loss: 4.030737, adv: 1.002643, recon: 0.090431, id: 0.124648] time: 2:54:41.834203
# Model weights saved. combined_model
# [Epoch 164/200] [Batch 400/400] [D loss: 0.000114, acc: 100%] [G loss: 3.969521, adv: 1.000674, recon: 0.088501, id: 0.102711] time: 2:55:46.605050
# Model weights saved. combined_model
# [Epoch 165/200] [Batch 400/400] [D loss: 0.000195, acc: 100%] [G loss: 3.902262, adv: 1.005513, recon: 0.084855, id: 0.100978] time: 2:56:50.652361
# Model weights saved. combined_model
# [Epoch 166/200] [Batch 400/400] [D loss: 0.000331, acc: 100%] [G loss: 3.745226, adv: 1.002911, recon: 0.077562, id: 0.125290] time: 2:57:54.642979
# Model weights saved. combined_model
# [Epoch 167/200] [Batch 400/400] [D loss: 0.000119, acc: 100%] [G loss: 3.790168, adv: 0.999330, recon: 0.078916, id: 0.117637] time: 2:58:59.054712
# Model weights saved. combined_model
# [Epoch 168/200] [Batch 400/400] [D loss: 0.000197, acc: 100%] [G loss: 3.701335, adv: 0.996442, recon: 0.075662, id: 0.124451] time: 3:00:04.867953
# Model weights saved. combined_model
# [Epoch 169/200] [Batch 400/400] [D loss: 0.000448, acc: 100%] [G loss: 3.916063, adv: 1.000945, recon: 0.085663, id: 0.113595] time: 3:01:09.317079
# Model weights saved. combined_model
# [Epoch 170/200] [Batch 400/400] [D loss: 0.000259, acc: 100%] [G loss: 3.899427, adv: 1.005755, recon: 0.084407, id: 0.131530] time: 3:02:13.150124
# Model weights saved. combined_model
# [Epoch 171/200] [Batch 400/400] [D loss: 0.000156, acc: 100%] [G loss: 3.801026, adv: 1.003127, recon: 0.080298, id: 0.097983] time: 3:03:16.908416
# Model weights saved. combined_model
# [Epoch 172/200] [Batch 400/400] [D loss: 0.000108, acc: 100%] [G loss: 3.734306, adv: 1.000824, recon: 0.077108, id: 0.117093] time: 3:04:21.219966
# Model weights saved. combined_model
# [Epoch 173/200] [Batch 400/400] [D loss: 0.000179, acc: 100%] [G loss: 3.980946, adv: 0.994253, recon: 0.089934, id: 0.130382] time: 3:05:26.679807
# Model weights saved. combined_model
# [Epoch 174/200] [Batch 400/400] [D loss: 0.000142, acc: 100%] [G loss: 3.962348, adv: 0.999818, recon: 0.086537, id: 0.139751] time: 3:06:30.610657
# Model weights saved. combined_model
# [Epoch 175/200] [Batch 400/400] [D loss: 0.000084, acc: 100%] [G loss: 4.202693, adv: 0.997780, recon: 0.096057, id: 0.107642] time: 3:07:33.801855
# Model weights saved. combined_model
# [Epoch 176/200] [Batch 400/400] [D loss: 0.000392, acc: 100%] [G loss: 3.957843, adv: 0.994753, recon: 0.088133, id: 0.136627] time: 3:08:37.575852
# Model weights saved. combined_model
# [Epoch 177/200] [Batch 400/400] [D loss: 0.000150, acc: 100%] [G loss: 3.835347, adv: 0.998433, recon: 0.081649, id: 0.112699] time: 3:09:42.193038
# Model weights saved. combined_model
# [Epoch 178/200] [Batch 400/400] [D loss: 0.000143, acc: 100%] [G loss: 3.806462, adv: 0.996210, recon: 0.079829, id: 0.123397] time: 3:10:47.963557
# Model weights saved. combined_model
# [Epoch 179/200] [Batch 400/400] [D loss: 0.000213, acc: 100%] [G loss: 3.883997, adv: 1.004700, recon: 0.083925, id: 0.120737] time: 3:11:51.721553
# Model weights saved. combined_model
# [Epoch 180/200] [Batch 400/400] [D loss: 0.000145, acc: 100%] [G loss: 3.777160, adv: 1.001357, recon: 0.079655, id: 0.114198] time: 3:12:56.005085
# Model weights saved. combined_model
# [Epoch 181/200] [Batch 400/400] [D loss: 0.000241, acc: 100%] [G loss: 3.963905, adv: 1.017817, recon: 0.084933, id: 0.113920] time: 3:13:59.732793
# Model weights saved. combined_model
# [Epoch 182/200] [Batch 400/400] [D loss: 0.000068, acc: 100%] [G loss: 3.610622, adv: 0.998851, recon: 0.071802, id: 0.104973] time: 3:15:04.354250
# Model weights saved. combined_model
# [Epoch 183/200] [Batch 400/400] [D loss: 0.001189, acc: 100%] [G loss: 4.014805, adv: 0.984988, recon: 0.091907, id: 0.108116] time: 3:16:10.420291
# Model weights saved. combined_model
# [Epoch 184/200] [Batch 400/400] [D loss: 0.001908, acc: 100%] [G loss: 3.652740, adv: 1.019657, recon: 0.071724, id: 0.105450] time: 3:17:13.530917
# Model weights saved. combined_model
# [Epoch 185/200] [Batch 400/400] [D loss: 0.000333, acc: 100%] [G loss: 3.786107, adv: 1.002858, recon: 0.078064, id: 0.114328] time: 3:18:18.296035
# Model weights saved. combined_model
# [Epoch 186/200] [Batch 400/400] [D loss: 0.000248, acc: 100%] [G loss: 3.967199, adv: 1.005289, recon: 0.087969, id: 0.104128] time: 3:19:22.758981
# Model weights saved. combined_model
# [Epoch 187/200] [Batch 400/400] [D loss: 0.000091, acc: 100%] [G loss: 3.858559, adv: 1.003895, recon: 0.082046, id: 0.100756] time: 3:20:27.336655
# Model weights saved. combined_model
# [Epoch 188/200] [Batch 400/400] [D loss: 0.000171, acc: 100%] [G loss: 3.719038, adv: 0.997414, recon: 0.076728, id: 0.118648] time: 3:21:31.025696
# Model weights saved. combined_model
# [Epoch 189/200] [Batch 400/400] [D loss: 0.000101, acc: 100%] [G loss: 3.917571, adv: 1.003116, recon: 0.085059, id: 0.121398] time: 3:22:37.368875
# Model weights saved. combined_model
# [Epoch 190/200] [Batch 400/400] [D loss: 0.000265, acc: 100%] [G loss: 4.019684, adv: 1.003598, recon: 0.088011, id: 0.132526] time: 3:23:41.754179
# Model weights saved. combined_model
# [Epoch 191/200] [Batch 400/400] [D loss: 0.000113, acc: 100%] [G loss: 3.538170, adv: 1.003566, recon: 0.067575, id: 0.113801] time: 3:24:45.846157
# Model weights saved. combined_model
# [Epoch 192/200] [Batch 400/400] [D loss: 0.000186, acc: 100%] [G loss: 3.806868, adv: 1.000659, recon: 0.079272, id: 0.109475] time: 3:25:50.659193
# Model weights saved. combined_model
# [Epoch 193/200] [Batch 400/400] [D loss: 0.000093, acc: 100%] [G loss: 3.873416, adv: 1.001143, recon: 0.083455, id: 0.134789] time: 3:26:55.523035
# Model weights saved. combined_model
# [Epoch 194/200] [Batch 400/400] [D loss: 0.000230, acc: 100%] [G loss: 3.676112, adv: 1.003375, recon: 0.073448, id: 0.124654] time: 3:28:00.623136
# Model weights saved. combined_model
# [Epoch 195/200] [Batch 400/400] [D loss: 0.109644, acc:  78%] [G loss: 3.925921, adv: 1.134034, recon: 0.072738, id: 0.121295] time: 3:29:07.221200
# Model weights saved. combined_model
# [Epoch 196/200] [Batch 400/400] [D loss: 0.000278, acc: 100%] [G loss: 3.822177, adv: 1.010086, recon: 0.081005, id: 0.109792] time: 3:30:12.292447
# Model weights saved. combined_model
# [Epoch 197/200] [Batch 400/400] [D loss: 0.000086, acc: 100%] [G loss: 3.674747, adv: 1.000023, recon: 0.074442, id: 0.101940] time: 3:31:17.587769
# Model weights saved. combined_model
# [Epoch 198/200] [Batch 400/400] [D loss: 0.000149, acc: 100%] [G loss: 4.081717, adv: 1.009706, recon: 0.091897, id: 0.118175] time: 3:32:21.952539
# Model weights saved. combined_model
# [Epoch 199/200] [Batch 400/400] [D loss: 0.000123, acc: 100%] [G loss: 3.833497, adv: 1.003128, recon: 0.080659, id: 0.120741] time: 3:33:26.420706
# Model weights saved. combined_model
# [Epoch 200/200] [Batch 400/400] [D loss: 0.000056, acc: 100%] [G loss: 3.602160, adv: 1.000431, recon: 0.072035, id: 0.097574] time: 3:34:32.314291
# Model weights saved. combined_model
# 2020-07-31T02:51:43.392014 End

# %%
gan.train(epochs=200, batch_size=1, sample_interval=400, save_interval=400)
gan.history.to_csv(os.path.join(OUTPUT_DIR_PATH, 'history_2020073103.csv')
